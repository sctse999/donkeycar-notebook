# %% [markdown]
# # Red line detector as a part

# %% [markdown]
# ## Import some libraries

# %%
import donkeycar as dk
import os
# Out:
# ________             ______                   _________
# ___  __ \_______________  /___________  __    __  ____/_____ ________
# __  / / /  __ \_  __ \_  //_/  _ \_  / / /    _  /    _  __ `/_  ___/
# _  /_/ // /_/ /  / / /  ,<  /  __/  /_/ /     / /___  / /_/ /_  /
# /_____/ \____//_/ /_//_/|_| \___/_\__, /      \____/  \__,_/ /_/
#                                  /____/
#
# using donkey v5.0.dev3 ...

# %%
# %run functions_donkey_car_parts.ipynb
# %run functions_red_line.ipynb

# %% [markdown]
# ## Loading myconfig

# %%
cfg = dk.load_config(config_path="/home/pi/mycar/config.py")

cfg.DRIVE_LOOP_HZ = 20
cfg.PATH_MASK = get_red_line_tub_images_path() + "/*.jpg"
# Out:
# INFO:donkeycar.config:loading config file: /home/pi/mycar/config.py
# INFO:donkeycar.config:loading personal config over-rides from myconfig.py

# %%
V = dk.vehicle.Vehicle()

add_user_controller(V, cfg, None, 'cam/image_array')
add_camera(V, cfg, "IMAGELIST")
# Out:
# INFO:donkeycar.parts.web_controller.web:Starting Donkey Server...
# INFO:donkeycar.parts.web_controller.web:You can now go to donkey-52a684.local:8887 to drive your car.
# INFO:donkeycar.vehicle:Adding part LocalWebController.
# INFO:donkeycar.parts.camera:2136 images loaded.
# INFO:donkeycar.parts.camera:['/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/0_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/1_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/2_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/3_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/4_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/5_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/6_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/7_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/8_cam_image_array_.jpg', '/home/pi/donkeycar-notebook/basic/resource/red_line_tub/images/9_cam_image_array_.jpg']
# INFO:donkeycar.vehicle:Adding part ImageListCamera.

# %% [markdown]
# ## Detect red line part

# %%
import donkeycar as dk

class CounterGenerator:
    def __init__(self):
        self.counter = 0
        pass
        
    def run(self, img):
        self.counter = self.counter + 1
        
        pct = detect_red_line(img)
        print(f"{self.counter}: {pct}")

# %%
# V.add(CounterGenerator(), inputs=['cam/image_array'], outputs=[])

# %%
'''
# Generate a red line detector that will be used to detect the red line on the track
This detector should count the number of red pixel in the image. If the number of red pixel is more than one third of the image, return true


'''

import numpy as np
import cv2

class RedLineDetector:
    def __init__(self):
        self.counter = 0
        self.red_line_detected = False
        
    def detect_red_line(self, image):
        # Convert the image to HSV color space
        hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
        
        # Define the range for red color
        lower_red = np.array([0, 100, 100])
        upper_red = np.array([10, 255, 255])


        # Create a mask for the red color
        mask = cv2.inRange(hsv_image, lower_red, upper_red)

        # Count the number of red pixels
        num_red_pixels = cv2.countNonZero(mask)

        # Get the total number of pixels in the image
        total_pixels = image.shape[0] * image.shape[1]

        print(f"{self.counter} : num_red_pixels = {num_red_pixels}")

        self.counter = self.counter + 1

        # Check if the number of red pixels is more than one third of the image
        if num_red_pixels > total_pixels / 3:
            self.red_line_detected = True

            return self.red_line_detected
        else:
            self.red_line_detected = False
            return self.red_line_detected

    def run(self, image):
        """
        The run function is called on each iteration of the vehicle loop
        """
        return self.detect_red_line(image)

    def shutdown(self):
        """
        Called when the part is about to be shut down
        """
        pass

    def update(self):
        """
        Called when the part receives a new value
        """
        pass

    def run_threaded(self, image):
        """
        The run_threaded function is called in a separate thread
        """
        return self.detect_red_line(image)

    def get_red_line_detected(self):
        """
        Returns the current state of red line detection
        """
        return self.red_line_detected

# %%
V.add(RedLineDetector(), inputs=['cam/image_array'], outputs=['detected'])
# Out:
# INFO:donkeycar.vehicle:Adding part RedLineDetector.

# %%
display_drive_url()

V.start(rate_hz=20, max_loop_count=400)
# Out:
# You can now go to <a href="http://192.168.8.191:8887" target="_blank">http://192.168.8.191:8887</a> to drive your car.
# INFO:donkeycar.vehicle:Starting vehicle at 20 Hz
# 0 : num_red_pixels = 0
# 1 : num_red_pixels = 0
# 2 : num_red_pixels = 0
# 3 : num_red_pixels = 0
# 4 : num_red_pixels = 0
# 5 : num_red_pixels = 0
# 6 : num_red_pixels = 0
# 7 : num_red_pixels = 0
# 8 : num_red_pixels = 0
# 9 : num_red_pixels = 0
# 10 : num_red_pixels = 0
# 11 : num_red_pixels = 0
# 12 : num_red_pixels = 0
# 13 : num_red_pixels = 0
# 14 : num_red_pixels = 0
# 15 : num_red_pixels = 0
# 16 : num_red_pixels = 0
# 17 : num_red_pixels = 0
# 18 : num_red_pixels = 0
# 19 : num_red_pixels = 0
# 20 : num_red_pixels = 0
# 21 : num_red_pixels = 0
# 22 : num_red_pixels = 0
# 23 : num_red_pixels = 0
# 24 : num_red_pixels = 0
# 25 : num_red_pixels = 0
# 26 : num_red_pixels = 0
# 27 : num_red_pixels = 0
# 28 : num_red_pixels = 0
# 29 : num_red_pixels = 0
# 30 : num_red_pixels = 0
# 31 : num_red_pixels = 0
# 32 : num_red_pixels = 0
# 33 : num_red_pixels = 0
# 34 : num_red_pixels = 0
# 35 : num_red_pixels = 0
# 36 : num_red_pixels = 0
# 37 : num_red_pixels = 0
# 38 : num_red_pixels = 10
# 39 : num_red_pixels = 10
# 40 : num_red_pixels = 3
# 41 : num_red_pixels = 0
# 42 : num_red_pixels = 3
# 43 : num_red_pixels = 0
# 44 : num_red_pixels = 0
# 45 : num_red_pixels = 0
# 46 : num_red_pixels = 0
# 47 : num_red_pixels = 0
# 48 : num_red_pixels = 0
# 49 : num_red_pixels = 0
# 50 : num_red_pixels = 0
# 51 : num_red_pixels = 0
# 52 : num_red_pixels = 0
# 53 : num_red_pixels = 0
# 54 : num_red_pixels = 0
# 55 : num_red_pixels = 0
# 56 : num_red_pixels = 0
# 57 : num_red_pixels = 0
# 58 : num_red_pixels = 0
# 59 : num_red_pixels = 0
# 60 : num_red_pixels = 0
# 61 : num_red_pixels = 0
# 62 : num_red_pixels = 0
# 63 : num_red_pixels = 0
# 64 : num_red_pixels = 0
# 65 : num_red_pixels = 0
# 66 : num_red_pixels = 0
# 67 : num_red_pixels = 0
# 68 : num_red_pixels = 0
# 69 : num_red_pixels = 0
# 70 : num_red_pixels = 0
# 71 : num_red_pixels = 0
# 72 : num_red_pixels = 0
# 73 : num_red_pixels = 0
# 74 : num_red_pixels = 0
# 75 : num_red_pixels = 0
# 76 : num_red_pixels = 0
# 77 : num_red_pixels = 0
# 78 : num_red_pixels = 0
# 79 : num_red_pixels = 0
# 80 : num_red_pixels = 0
# 81 : num_red_pixels = 0
# 82 : num_red_pixels = 0
# 83 : num_red_pixels = 0
# 84 : num_red_pixels = 0
# 85 : num_red_pixels = 0
# 86 : num_red_pixels = 0
# 87 : num_red_pixels = 0
# 88 : num_red_pixels = 0
# 89 : num_red_pixels = 0
# 90 : num_red_pixels = 0
# 91 : num_red_pixels = 0
# 92 : num_red_pixels = 0
# 93 : num_red_pixels = 0
# 94 : num_red_pixels = 0
# 95 : num_red_pixels = 0
# 96 : num_red_pixels = 0
# 97 : num_red_pixels = 0
# 98 : num_red_pixels = 0
# 99 : num_red_pixels = 0
# 100 : num_red_pixels = 0
# 101 : num_red_pixels = 0
# 102 : num_red_pixels = 0
# 103 : num_red_pixels = 0
# 104 : num_red_pixels = 0
# 105 : num_red_pixels = 0
# 106 : num_red_pixels = 0
# 107 : num_red_pixels = 0
# 108 : num_red_pixels = 0
# 109 : num_red_pixels = 0
# 110 : num_red_pixels = 0
# 111 : num_red_pixels = 0
# 112 : num_red_pixels = 0
# 113 : num_red_pixels = 0
# 114 : num_red_pixels = 0
# 115 : num_red_pixels = 0
# 116 : num_red_pixels = 0
# 117 : num_red_pixels = 0
# 118 : num_red_pixels = 0
# 119 : num_red_pixels = 0
# 120 : num_red_pixels = 0
# 121 : num_red_pixels = 0
# 122 : num_red_pixels = 0
# 123 : num_red_pixels = 0
# 124 : num_red_pixels = 0
# 125 : num_red_pixels = 0
# 126 : num_red_pixels = 0
# 127 : num_red_pixels = 0
# 128 : num_red_pixels = 0
# 129 : num_red_pixels = 0
# 130 : num_red_pixels = 0
# 131 : num_red_pixels = 0
# 132 : num_red_pixels = 0
# 133 : num_red_pixels = 0
# 134 : num_red_pixels = 0
# 135 : num_red_pixels = 0
# 136 : num_red_pixels = 0
# 137 : num_red_pixels = 0
# 138 : num_red_pixels = 0
# 139 : num_red_pixels = 0
# 140 : num_red_pixels = 0
# 141 : num_red_pixels = 0
# 142 : num_red_pixels = 0
# 143 : num_red_pixels = 0
# 144 : num_red_pixels = 0
# 145 : num_red_pixels = 0
# 146 : num_red_pixels = 0
# 147 : num_red_pixels = 0
# 148 : num_red_pixels = 0
# 149 : num_red_pixels = 0
# 150 : num_red_pixels = 0
# 151 : num_red_pixels = 0
# 152 : num_red_pixels = 0
# 153 : num_red_pixels = 0
# 154 : num_red_pixels = 0
# 155 : num_red_pixels = 0
# 156 : num_red_pixels = 0
# 157 : num_red_pixels = 0
# 158 : num_red_pixels = 4
# 159 : num_red_pixels = 4
# 160 : num_red_pixels = 10
# 161 : num_red_pixels = 4
# 162 : num_red_pixels = 2
# 163 : num_red_pixels = 37
# 164 : num_red_pixels = 20
# 165 : num_red_pixels = 20
# 166 : num_red_pixels = 70
# 167 : num_red_pixels = 56
# 168 : num_red_pixels = 56
# 169 : num_red_pixels = 119
# 170 : num_red_pixels = 413
# 171 : num_red_pixels = 748
# 172 : num_red_pixels = 1330
# 173 : num_red_pixels = 97
# 174 : num_red_pixels = 0
# 175 : num_red_pixels = 0
# 176 : num_red_pixels = 0
# 177 : num_red_pixels = 0
# 178 : num_red_pixels = 0
# 179 : num_red_pixels = 0
# 180 : num_red_pixels = 0
# 181 : num_red_pixels = 0
# 182 : num_red_pixels = 0
# 183 : num_red_pixels = 0
# 184 : num_red_pixels = 0
# 185 : num_red_pixels = 0
# 186 : num_red_pixels = 0
# 187 : num_red_pixels = 0
# 188 : num_red_pixels = 0
# 189 : num_red_pixels = 0
# 190 : num_red_pixels = 0
# 191 : num_red_pixels = 0
# 192 : num_red_pixels = 0
# 193 : num_red_pixels = 0
# 194 : num_red_pixels = 0
# 195 : num_red_pixels = 0
# 196 : num_red_pixels = 0
# 197 : num_red_pixels = 0
# 198 : num_red_pixels = 0
# 199 : num_red_pixels = 0
# 200 : num_red_pixels = 0
# 201 : num_red_pixels = 0
# 202 : num_red_pixels = 0
# 203 : num_red_pixels = 0
# 204 : num_red_pixels = 0
# 205 : num_red_pixels = 0
# 206 : num_red_pixels = 0
# 207 : num_red_pixels = 0
# 208 : num_red_pixels = 0
# 209 : num_red_pixels = 0
# 210 : num_red_pixels = 0
# 211 : num_red_pixels = 0
# 212 : num_red_pixels = 0
# 213 : num_red_pixels = 0
# 214 : num_red_pixels = 0
# 215 : num_red_pixels = 0
# 216 : num_red_pixels = 0
# 217 : num_red_pixels = 0
# 218 : num_red_pixels = 0
# 219 : num_red_pixels = 0
# 220 : num_red_pixels = 0
# 221 : num_red_pixels = 0
# 222 : num_red_pixels = 0
# 223 : num_red_pixels = 0
# 224 : num_red_pixels = 0
# 225 : num_red_pixels = 0
# 226 : num_red_pixels = 0
# 227 : num_red_pixels = 0
# 228 : num_red_pixels = 0
# 229 : num_red_pixels = 0
# 230 : num_red_pixels = 0
# 231 : num_red_pixels = 0
# 232 : num_red_pixels = 0
# 233 : num_red_pixels = 0
# 234 : num_red_pixels = 0
# 235 : num_red_pixels = 0
# 236 : num_red_pixels = 0
# 237 : num_red_pixels = 0
# 238 : num_red_pixels = 0
# 239 : num_red_pixels = 0
# 240 : num_red_pixels = 0
# 241 : num_red_pixels = 0
# 242 : num_red_pixels = 0
# 243 : num_red_pixels = 0
# 244 : num_red_pixels = 0
# 245 : num_red_pixels = 0
# 246 : num_red_pixels = 0
# 247 : num_red_pixels = 0
# 248 : num_red_pixels = 0
# 249 : num_red_pixels = 0
# 250 : num_red_pixels = 0
# 251 : num_red_pixels = 1
# 252 : num_red_pixels = 1
# 253 : num_red_pixels = 2
# 254 : num_red_pixels = 1
# 255 : num_red_pixels = 5
# 256 : num_red_pixels = 3
# 257 : num_red_pixels = 0
# 258 : num_red_pixels = 0
# 259 : num_red_pixels = 3
# 260 : num_red_pixels = 4
# 261 : num_red_pixels = 0
# 262 : num_red_pixels = 0
# 263 : num_red_pixels = 0
# 264 : num_red_pixels = 0
# 265 : num_red_pixels = 0
# 266 : num_red_pixels = 0
# 267 : num_red_pixels = 0
# 268 : num_red_pixels = 0
# 269 : num_red_pixels = 0
# 270 : num_red_pixels = 0
# 271 : num_red_pixels = 0
# 272 : num_red_pixels = 0
# 273 : num_red_pixels = 0
# 274 : num_red_pixels = 0
# 275 : num_red_pixels = 0
# 276 : num_red_pixels = 0
# 277 : num_red_pixels = 0
# 278 : num_red_pixels = 0
# 279 : num_red_pixels = 0
# 280 : num_red_pixels = 0
# 281 : num_red_pixels = 0
# 282 : num_red_pixels = 0
# 283 : num_red_pixels = 0
# 284 : num_red_pixels = 0
# 285 : num_red_pixels = 0
# 286 : num_red_pixels = 0
# 287 : num_red_pixels = 0
# 288 : num_red_pixels = 0
# 289 : num_red_pixels = 0
# 290 : num_red_pixels = 0
# 291 : num_red_pixels = 0
# 292 : num_red_pixels = 0
# 293 : num_red_pixels = 0
# 294 : num_red_pixels = 0
# 295 : num_red_pixels = 0
# 296 : num_red_pixels = 0
# 297 : num_red_pixels = 0
# 298 : num_red_pixels = 0
# 299 : num_red_pixels = 0
# 300 : num_red_pixels = 0
# 301 : num_red_pixels = 0
# 302 : num_red_pixels = 0
# 303 : num_red_pixels = 0
# 304 : num_red_pixels = 0
# 305 : num_red_pixels = 0
# 306 : num_red_pixels = 0
# 307 : num_red_pixels = 0
# 308 : num_red_pixels = 0
# 309 : num_red_pixels = 0
# 310 : num_red_pixels = 0
# 311 : num_red_pixels = 0
# 312 : num_red_pixels = 0
# 313 : num_red_pixels = 0
# 314 : num_red_pixels = 0
# 315 : num_red_pixels = 0
# 316 : num_red_pixels = 0
# 317 : num_red_pixels = 0
# 318 : num_red_pixels = 0
# 319 : num_red_pixels = 0
# 320 : num_red_pixels = 0
# 321 : num_red_pixels = 0
# 322 : num_red_pixels = 0
# 323 : num_red_pixels = 0
# 324 : num_red_pixels = 0
# 325 : num_red_pixels = 0
# 326 : num_red_pixels = 0
# 327 : num_red_pixels = 0
# 328 : num_red_pixels = 0
# 329 : num_red_pixels = 0
# 330 : num_red_pixels = 0
# 331 : num_red_pixels = 0
# 332 : num_red_pixels = 0
# 333 : num_red_pixels = 0
# 334 : num_red_pixels = 0
# 335 : num_red_pixels = 0
# 336 : num_red_pixels = 0
# 337 : num_red_pixels = 0
# 338 : num_red_pixels = 0
# 339 : num_red_pixels = 0
# 340 : num_red_pixels = 0
# 341 : num_red_pixels = 0
# 342 : num_red_pixels = 0
# 343 : num_red_pixels = 0
# 344 : num_red_pixels = 0
# 345 : num_red_pixels = 0
# 346 : num_red_pixels = 0
# 347 : num_red_pixels = 0
# 348 : num_red_pixels = 0
# 349 : num_red_pixels = 0
# 350 : num_red_pixels = 0
# 351 : num_red_pixels = 0
# 352 : num_red_pixels = 1
# 353 : num_red_pixels = 0
# 354 : num_red_pixels = 0
# 355 : num_red_pixels = 0
# 356 : num_red_pixels = 0
# 357 : num_red_pixels = 0
# 358 : num_red_pixels = 0
# 359 : num_red_pixels = 0
# 360 : num_red_pixels = 0
# 361 : num_red_pixels = 0
# 362 : num_red_pixels = 0
# 363 : num_red_pixels = 0
# 364 : num_red_pixels = 0
# 365 : num_red_pixels = 0
# 366 : num_red_pixels = 0
# 367 : num_red_pixels = 0
# 368 : num_red_pixels = 0
# 369 : num_red_pixels = 0
# 370 : num_red_pixels = 0
# 371 : num_red_pixels = 0
# 372 : num_red_pixels = 0
# 373 : num_red_pixels = 0
# 374 : num_red_pixels = 0
# 375 : num_red_pixels = 0
# 376 : num_red_pixels = 0
# 377 : num_red_pixels = 0
# 378 : num_red_pixels = 0
# 379 : num_red_pixels = 0
# 380 : num_red_pixels = 0
# 381 : num_red_pixels = 0
# 382 : num_red_pixels = 0
# 383 : num_red_pixels = 0
# 384 : num_red_pixels = 0
# 385 : num_red_pixels = 0
# 386 : num_red_pixels = 0
# 387 : num_red_pixels = 0
# 388 : num_red_pixels = 0
# 389 : num_red_pixels = 0
# 390 : num_red_pixels = 0
# 391 : num_red_pixels = 0
# 392 : num_red_pixels = 0
# 393 : num_red_pixels = 0
# 394 : num_red_pixels = 0
# 395 : num_red_pixels = 0
# 396 : num_red_pixels = 0
# INFO:donkeycar.vehicle:Vehicle executed 400 steps in 19.994169235229492 seconds.
# INFO:donkeycar.vehicle:Shutting down vehicle and its parts...
# INFO:donkeycar.vehicle:Part Profile Summary: (times in ms)
# INFO:donkeycar.vehicle:
# +--------------------+------+------+------+------+------+------+-------+
# |        part        | max  | min  | avg  | 50%  | 90%  | 99%  | 99.9% |
# +--------------------+------+------+------+------+------+------+-------+
# | LocalWebController | 0.53 | 0.13 | 0.23 | 0.24 | 0.31 | 0.42 |  0.53 |
# |  ImageListCamera   | 3.17 | 0.99 | 1.72 | 1.98 | 2.35 | 2.61 |  2.97 |
# |  RedLineDetector   | 2.76 | 0.35 | 0.69 | 0.72 | 0.99 | 1.39 |  2.59 |
# +--------------------+------+------+------+------+------+------+-------+
# 397 : num_red_pixels = 0
# 398 : num_red_pixels = 0
# 399 : num_red_pixels = 0
# (400, 19.994169235229492)

# %%
V.stop()
# Out:
# INFO:donkeycar.vehicle:Shutting down vehicle and its parts...
# INFO:donkeycar.vehicle:Part Profile Summary: (times in ms)
# INFO:donkeycar.vehicle:
# +--------------------+------+------+------+------+------+------+-------+
# |        part        | max  | min  | avg  | 50%  | 90%  | 99%  | 99.9% |
# +--------------------+------+------+------+------+------+------+-------+
# | LocalWebController | 0.53 | 0.13 | 0.23 | 0.24 | 0.31 | 0.42 |  0.53 |
# |  ImageListCamera   | 3.17 | 0.99 | 1.72 | 1.98 | 2.35 | 2.61 |  2.97 |
# |  RedLineDetector   | 2.76 | 0.35 | 0.69 | 0.72 | 0.99 | 1.39 |  2.59 |
# +--------------------+------+------+------+------+------+------+-------+

# %% [markdown]
# ## Define Camera Helper function

# %%
# !netstat -an -A inet | grep 8887
# Out:
# tcp        0      0 0.0.0.0:8887            0.0.0.0:*               LISTEN

# %% [markdown]
# ## Kill process listening to 8887

# %%
# !kill -9 $(lsof -t -i:8887)
